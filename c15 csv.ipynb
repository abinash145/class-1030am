# %% [raw]
# try:
#
#     b = open("data.csv","x")
#     b.close()
# except:
#     print("The file is already there")

# %%
import csv
csvfile = open('data.csv')
reader = csv.DictReader(csvfile)
for row in reader:
    print(row)
data.csv.clos
# Out:
# {'Name': 'Ram', 'Age': '67', 'Address': 'Kathmandu', 'Phone': '98565682478'}
# {'Name': 'Shyam', 'Age': '34', 'Address': 'Patan', 'Phone': '67989'}
# {'Name': 'Hari', 'Age': '32', 'Address': 'Bara', 'Phone': '232323'}
# {'Name': 'Nabin', 'Age': '24', 'Address': 'Simara', 'Phone': '344334'}
# {'Name': 'Rita', 'Age': '88', 'Address': 'Nagarkot', 'Phone': '234'}
# {'Name': 'Sabit', 'Age': '64', 'Address': 'Bhaktapur', 'Phone': '24342'}

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df
# Out:
#     Name  Age    Address        Phone
# 0    Ram   67  Kathmandu  98565682478
# 1  Shyam   34      Patan        67989
# 2   Hari   32       Bara       232323
# 3  Nabin   24     Simara       344334
# 4   Rita   88   Nagarkot          234
# 5  Sabit   64  Bhaktapur        24342

# %%
import pandas as pd
df = pd.read_csv('data.csv',nrows=3)
df
# Out:
#     Name  Age    Address        Phone
# 0    Ram   67  Kathmandu  98565682478
# 1  Shyam   34      Patan        67989
# 2   Hari   32       Bara       232323

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df.head(4)
# df.tail()
# Out:
#     Name  Age    Address        Phone
# 0    Ram   67  Kathmandu  98565682478
# 1  Shyam   34      Patan        67989
# 2   Hari   32       Bara       232323
# 3  Nabin   24     Simara       344334

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col='SN')
df
# Out:
#      Name  Age    Address        Phone
# SN
# 1     Ram   67  Kathmandu  98565682478
# 2   Shyam   34      Patan        67989
# 3    Hari   32       Bara       232323
# 4   Nabin   24     Simara       344334
# 5    Rita   88   Nagarkot          234
# 6   Sabit   64  Bhaktapur        24342

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col='SN')
df.iloc[0:5,0:3]
# Out:
#      Name  Age    Address
# SN
# 1     Ram   67  Kathmandu
# 2   Shyam   34      Patan
# 3    Hari   32       Bara
# 4   Nabin   24     Simara
# 5    Rita   88   Nagarkot

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col='Name')
df.loc["Ram":"Nabin"]
# Out:
#        SN  Age    Address        Phone
# Name
# Ram     1   67  Kathmandu  98565682478
# Shyam   2   34      Patan        67989
# Hari    3   32       Bara       232323
# Nabin   4   24     Simara       344334

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col='SN')
df[df["Address"]=="Kathmandu"]
# Out:
#    Name  Age    Address        Phone
# SN
# 1   Ram   67  Kathmandu  98565682478

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col='Name',usecols=["SN","Name"])
df
# Out:
#        SN
# Name
# Ram     1
# Shyam   2
# Hari    3
# Nabin   4
# Rita    5
# Sabit   6

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col='SN')
df1=df[(df["Age"]>20) & (df['Address']=='Kathmandu')]
df1.t0_csv('df1.csv')
df1
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-44-5bba08d29267> in <module>
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('data.csv',index_col='SN')
#       3 df1=df[(df["Age"]>20) & (df['Address']=='Kathmandu')]
#       4 df1.t0_csv('df1.csv')
#       5 df1
#
# ...

# %%
import csv
fields = [7,"Hari",78,"Kathmandu",9898798798]
f= open('data.csv','a')
x=csv.writer(f)
x.writerow(fields)
f.close()

# %%
a=[["Name","Price","Quantity","Total"],["Apple",100,2,200],[]]
import csv
f=open("data.csv",'a')
x=csv.writer(f)
for i in a:
    x.writerow(i)
f.close()

# %%
DictWriter()
DataFrame()

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'SN') #df = data frame
df1 = df[(df['Age']>20) & (df['Address'] == 'Kathmandu')]
df1.to_csv('df1.csv')
df1
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-46-cc9554dfb081> in <module>
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('data.csv',index_col = 'SN') #df = data frame
#       3 df1 = df[(df['Age']>20) & (df['Address'] == 'Kathmandu')]
#       4 df1.to_csv('df1.csv')
#       5 df1
#
# ...
